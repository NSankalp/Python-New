# %% [markdown]
# <a href="https://colab.research.google.com/github/NSankalp/Python-New/blob/Module_5/Module_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Write a Python program to check that a string contains only a certain set of characters (in this
# case a-z, A-Z and 0-9).

# %%
import re
a="^[a-zA-Z0-9_ -]*$"
s=str(input())
c=bool(re.match(a,s))
print(c)
# Out:
# srh is the best
# True

# %% [markdown]
# Write a Python program that matches a string that has an a followed by zero or more b's

# %%
import re
